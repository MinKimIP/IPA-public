# %% [markdown]
# <a href="https://colab.research.google.com/github/MinKimIP/IPA-public/blob/master/data_request/2020-03-17%20Cayman%20Islands%20Trade%20Mark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Request
#
# 27 February 2020
#
# Customer asks if sa2 and lga information can be obtained from IPGOD 2019.
#
# ---
#
# This data request will be answered using [IPGOD 2019](https://data.gov.au/data/dataset/intellectual-property-government-open-data-2019).
#
# We note that IPGOD 2019 has many data quality issues.

# %% [markdown]
# ## Scripts
#
# Run the cell below without any changes.

# %%
import pandas as pd
import plotly.express as px

# data sources

def ip_data(ip_type, table):
    url_base = 'https://data.gov.au/data/dataset/a4210de2-9cbb-4d43-848d-46138fefd271/resource/'
    url = {'patent': {'process': '8fa6db74-a461-47f1-acc6-2e0cf7f06bd5/download/ipgod107.csv',
                      'applicant': '846990df-db42-4ad7-bbd6-567fd37a2797/download/ipgod102.csv',
                      'classification': '5aeec421-dddc-4c22-a66a-bfc5ad22947f/download/ipgod104.csv'},
           'trademark': {'process': '4dec358e-14ff-45ef-8b3e-b27274347e23/download/ipgod203.csv',
                         'applicant': 'aae1c14d-f8c0-4540-b5d3-1ed21500271e/download/ipgod202.csv',
                         'classification': 'fb505762-ab2a-4f56-999d-9bedd1da2ad5/download/ipgod204.csv'},
           'design': {'process': '9003a068-82fd-410d-a193-d54b8bc1f171/download/ipgod303.csv',
                      'applicant': '4b802e80-c667-4b84-8f50-72c2624c59c1/download/ipgod302.csv',
                      'classification': 'b01f7e00-a718-4e2d-9ffb-14938fd7dba9/download/ipgod304.csv'}}
    
    df = pd.read_csv(url_base+url[ip_type][table], low_memory=False)
    df = parse_dates(df)

    return df


main_key = {'patent': 'australian_appl_no',
            'trademark': 'tm_number',
            'design': 'application_id'}


# pipe components

def parse_dates(df):
    for column in df.columns:
        if "date" in column:
            df[column] = pd.to_datetime(df[column])
    
    return df

# %% [markdown]
# ## Get data

# %%
tm_applications = ip_data('trademark', 'process')
tm_applicants = ip_data('trademark', 'applicant')
tm = tm_applications.merge(tm_applicants, on='tm_number', how='left')
del tm_applications
del tm_applicants
tm.sample(n=10)
# Out:
#          tm_number  ...         acn
# 614611     1094046  ...  55161674.0
# 1569890     951688  ...  70857279.0
# 732166     1107180  ...         NaN
# 82195      1253947  ...         NaN
# 1061639    1823553  ...         NaN
# 740915     1254328  ...         NaN
# 521580      733646  ...  73011702.0
# 880566     1268114  ...         NaN
# 1508963    1787078  ...         NaN
# 1045304    1566853  ...  92783278.0
#
# [10 rows x 35 columns]

# %% [markdown]
# ## Manipulate the data, ready for aggregation

# %%
df = (tm[['tm_number', 'lodgement_date', 'sa2_name', 'lga_name']]
        .dropna()
        .assign(lodgement_year = lambda x: x['lodgement_date'].dt.year.astype(int))
        .drop(columns='lodgement_date')
        .query('lodgement_year >= 2000')
        .query('lodgement_year <= 2018')
        .drop_duplicates())

# save for downloading
df.to_csv('trademark.csv', index=False, encoding='utf-8')

df.sample(n=10)
# Out:
#          tm_number  ... lodgement_year
# 52309      1299677  ...           2009
# 530112     1678446  ...           2015
# 1606750     868641  ...           2001
# 245669     1802167  ...           2016
# 1308846     945326  ...           2003
# 900339     1945501  ...           2018
# 1445334    1578401  ...           2013
# 1265700    1226361  ...           2008
# 1001345    1521498  ...           2012
# 1613089    1336188  ...           2009
#
# [10 rows x 4 columns]

# %%
by_sa2 = df[['sa2_name', 'lodgement_year', 'tm_number']].groupby(['sa2_name', 'lodgement_year']).count().reset_index()

px.line(by_sa2, x="lodgement_year", y="tm_number", color="sa2_name")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3b0bf19c-2f12-4d21-a0e5-b1c1b6d23263" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3b0bf19c-2f12-4d21-a0e5-b1c1b6d23263")) {
#                     Plotly.newPlot(
#                         '3b0bf19c-2f12-4d21-a0e5-b1c1b6d23263',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "sa2_name=ACT - South West<br>lodgement_year=%{x}<br>tm_number=%{y}", "legendgroup": "sa2_name=ACT - South West", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "sa2_name=ACT - South West", "showlegend": true, "type": "scattergl", "x": [2003, 2004, 2005, 2006, 2011, 2018], "xaxis": "x", "y": [1, 1, 2, 1, 1, 1], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "sa2_name=APY Lands<br>lodgement_year=%{x}<br>tm_number=%{y}", "legendgroup": "sa2_name=APY Lands", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "sa2_name=APY Lands", "showlegend": true, "type": "scattergl", "x": [2006], "xaxis": "x", "y": [2], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "sa2_name=Abbotsford<br>lodgement_year=%{x}<br>tm_number=%{y}", "legendgroup": "sa2_name=Abbotsford", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "sa2_name=Abbotsford", "showlegend": true, "type": "scattergl", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [72, 57, 42, 62, 67, 78, 75, 91, 47, 82, 64, 48, 76, 91, 73, 77, 61, 68, 75], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "sa2_name=Aberfoyle Park<br>lodgement_year=%{x}<br>tm_number=%{y}", "legendgroup": "sa2_name=Aberfoyle Park", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "sa2_name=Aberfoyle Park", "showlegend": true, "type": "scattergl", "x": [2000, 2001, 2002, 2003, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [4, 2, 2, 4, 2, 1, 11, 4, 5, 5, 4, 2, 5, 3, 3, 5, 8, 12], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "sa2_name=Acacia Gardens<br>lodgement_year=%{x}<br>tm_number=%{y}", "legendgroup": "sa2_name=Acacia Gardens", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "sa2_name=Acacia Gardens", "showlegend": true, "type": "scattergl", "x": [2001, 2004, 2006, 2007, 2008, 2012, 2014, 2015, 2016], "xaxis": "x", "y": [1, 3, 1, 2, 1, 4, 1, 1, 2], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "sa2_name=Acton<br>lodgement_year=%{x}<br>tm_number=%{y}", "legendgroup": "sa2_name=Acton", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "sa2_name=Acton", "showlegend": true, "type": "scattergl", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [5, 28, 20, 6, 5, 3, 10, 13, 3, 7, 1, 8, 4, 1, 7, 9, 4, 10], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "sa2_name=Acton - Upper Burnie<br>lodgement_year=%{x}<br>tm_number=%{y}", "legendgroup": "sa2_name=Acton - Upper Burnie", "line": {"color": "#FF6692", "dash": "solid"}, "mode": "lines", "name": "sa2_name=Acton - Upper Burnie", "showlegend": true, "type": "scattergl", "x": [2004, 2010, 2011], "xaxis": "x", "y": [1, 1, 1], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "sa2_name=Adamstown - Kotara<br>lodgement_year=%{x}<br>tm_number=%{y}", "legendgroup": "sa2_name=Adamstown - Kotara", "line": {"color": "#B6E880", "dash": "solid"}, "mode": "lines", "name": "sa2_name=Adamstown - Kotara", "showlegend": true, "type": "scattergl", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [5, 3, 8, 6, 4, 10, 8, 11, 16, 16, 13, 10, 20, 11, 13, 22, 27, 30, 22], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "sa2_name=Adelaide<br>lodgement_year=%{x}<br>tm_number=%{y}", "legendgroup": "sa2_name=Adelaide", "line": {"color": "#FF97FF", "dash": "solid"}, "mode": "lines", "name": "sa2_name=Adelaide", "showlegend": true, "type": "scattergl", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012 ...

# %%
by_lga = df[['lga_name', 'lodgement_year', 'tm_number']].groupby(['lga_name', 'lodgement_year']).count().reset_index()

px.line(by_lga, x="lodgement_year", y="tm_number", color="lga_name")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a4e3b4ab-9a9c-4e0c-abed-951480951c54" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a4e3b4ab-9a9c-4e0c-abed-951480951c54")) {
#                     Plotly.newPlot(
#                         'a4e3b4ab-9a9c-4e0c-abed-951480951c54',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "lga_name=Adelaide (C)<br>lodgement_year=%{x}<br>tm_number=%{y}", "legendgroup": "lga_name=Adelaide (C)", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "lga_name=Adelaide (C)", "showlegend": true, "type": "scattergl", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [235, 300, 302, 339, 376, 418, 359, 311, 332, 339, 232, 256, 243, 270, 302, 368, 357, 424, 244], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "lga_name=Adelaide Hills (DC)<br>lodgement_year=%{x}<br>tm_number=%{y}", "legendgroup": "lga_name=Adelaide Hills (DC)", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "lga_name=Adelaide Hills (DC)", "showlegend": true, "type": "scattergl", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [49, 37, 45, 43, 73, 55, 45, 36, 49, 35, 18, 35, 43, 34, 40, 61, 45, 46, 31], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "lga_name=Adelaide Plains (DC)<br>lodgement_year=%{x}<br>tm_number=%{y}", "legendgroup": "lga_name=Adelaide Plains (DC)", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "lga_name=Adelaide Plains (DC)", "showlegend": true, "type": "scattergl", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2008, 2009, 2011, 2012, 2013, 2014, 2016, 2017], "xaxis": "x", "y": [3, 1, 4, 3, 10, 3, 3, 7, 1, 2, 2, 3, 1, 2], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "lga_name=Albany (C)<br>lodgement_year=%{x}<br>tm_number=%{y}", "legendgroup": "lga_name=Albany (C)", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "lga_name=Albany (C)", "showlegend": true, "type": "scattergl", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [11, 17, 14, 13, 22, 10, 42, 9, 12, 10, 9, 18, 28, 9, 6, 10, 25, 28, 11], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "lga_name=Albury (C)<br>lodgement_year=%{x}<br>tm_number=%{y}", "legendgroup": "lga_name=Albury (C)", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "lga_name=Albury (C)", "showlegend": true, "type": "scattergl", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [12, 23, 37, 33, 35, 25, 53, 32, 24, 41, 26, 36, 34, 36, 34, 28, 32, 49, 34], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "lga_name=Alexandrina (DC)<br>lodgement_year=%{x}<br>tm_number=%{y}", "legendgroup": "lga_name=Alexandrina (DC)", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "lga_name=Alexandrina (DC)", "showlegend": true, "type": "scattergl", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [33, 14, 17, 15, 27, 29, 31, 17, 12, 27, 15, 13, 16, 20, 15, 35, 32, 18, 17], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "lga_name=Alice Springs (T)<br>lodgement_year=%{x}<br>tm_number=%{y}", "legendgroup": "lga_name=Alice Springs (T)", "line": {"color": "#FF6692", "dash": "solid"}, "mode": "lines", "name": "lga_name=Alice Springs (T)", "showlegend": true, "type": "scattergl", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "xaxis": "x", "y": [14, 16, 11, 10, 17, 12, 22, 8, 18, 14, 9, 9, 9, 20, 8, 12, 14, 11, 17], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "lga_name=Alpine (S)<br>lodgement_year=%{x}<br>tm_number=%{y}", "legendgroup": "lga_name=Alpine (S)", "line": {"color": "#B6E880", "dash": "solid"}, "mode": "lines", "name": "lga_name=Alpine (S)", "showlegend": true, "typ ...
